# %% [markdown]
# <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image13.png" style="width:2.75in;height:1.01389in" /><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image14.png" style="width:2.73611in;height:0.13697in" />
#
# > <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image1.png" style="width:7.33333in;height:3.68056in" />
#
# <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image2.png" style="width:0.1375in;height:0.38889in" />
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image3.png" style="width:1.625in;height:0.20833in" /></p>
# </blockquote></th>
# <th><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image4.png" style="width:0.34722in;height:0.15278in" /></th>
# <th><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image5.png" style="width:0.51389in;height:0.18056in" /></th>
# <th><blockquote>
# <p><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image6.png" style="width:0.51389in;height:0.18056in" /></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image7.png" style="width:2.5in;height:0.31944in" /></td>
# <td><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image8.png" style="width:0.51389in;height:0.15278in" /></td>
# <td><blockquote>
# <p><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image9.png" style="width:0.51389in;height:0.15278in" /></p>
# </blockquote></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image10.png" style="width:7.34722in;height:1.20833in" />
# >
# > <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image11.png" style="width:4.15694in;height:2.63055in" />
# >
# > <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image12.png" style="width:2.01389in;height:0.26389in" />
# >
# > <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image15.png" style="width:7.34722in;height:0.76389in" />
# >
# > <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image16.png" style="width:4.15694in;height:2.63055in" />
#
# <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image17.png" style="width:7.41667in;height:2.5in" />
#
# > <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image18.png" style="width:4.0625in;height:2.77778in" />
# >
# > <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image19.png" style="width:1.93056in;height:0.26389in" />
#
# <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image23.png" style="width:7.43056in;height:4.41667in" /><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image24.png" style="width:0.1375in;height:0.40076in" /><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image25.png" style="width:1.55556in;height:0.19444in" /><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image26.png" style="width:0.34722in;height:0.16667in" /><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image27.png" style="width:0.51389in;height:0.18056in" /><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image28.png" style="width:0.51389in;height:0.16667in" /><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image29.png" style="width:1.625in;height:0.19444in" /><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image30.png" style="width:0.34722in;height:0.16667in" /><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image31.png" style="width:0.51389in;height:0.16667in" /><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image32.png" style="width:0.51389in;height:0.18056in" /><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image33.png" style="width:2.40278in;height:0.20833in" /><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image14.png" style="width:2.73611in;height:0.13697in" />
#
# <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image20.png" style="width:7.43056in;height:1.25in" />
#
# > <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image21.png" style="width:3.84444in;height:2.77639in" />
# >
# > <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image22.png" style="width:2.02778in;height:0.26389in" />
#
# <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image36.png" style="width:7.43056in;height:3.20833in" /><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image37.png" style="width:3.52917in;height:0.13689in" />
#
# <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image34.png" style="width:7.41667in;height:5.43056in" />
#
# > <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image35.png" style="width:4.86111in;height:0.26389in" />
#
# <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image38.png" style="width:7.43056in;height:2.86111in" />
#
# <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image39.png" style="width:7.43056in;height:2.91667in" />
#
# > <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image40.png" style="width:1.94444in;height:0.27778in" />
#
# <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image43.png" style="width:4.22917in;height:2.63237in" /><img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image44.png" style="width:0.45417in;height:0.45417in" />
#
# <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image41.png" style="width:7.43056in;height:0.75in" />
#
# <img src="attachment:vertopal_71f678a62886478aae3b09dbb1e4ce86/media/image42.png" style="width:7.43056in;height:1.56944in" />
